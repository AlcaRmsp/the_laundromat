# %% [markdown]
# ## Data Exploration

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Uploading Dataset

# %%
import os
os.getcwd()
# Out:
# '/Users/tajania/code/AlcaRmsp/the_laundromat'

# %%
csv_path = '/Users/tajania/code/AlcaRmsp/the_laundromat'
csv_path
# Out:
# '/Users/tajania/code/AlcaRmsp/the_laundromat'

# %%
import pandas as pd
df=pd.read_csv(os.path.join(csv_path, 'raw_data/data.csv'))
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
df.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  6.362620e+06  6.362620e+06   6.362620e+06    6.362620e+06
# mean   2.433972e+02  1.798619e+05   8.338831e+05    8.551137e+05
# std    1.423320e+02  6.038582e+05   2.888243e+06    2.924049e+06
# min    1.000000e+00  0.000000e+00   0.000000e+00    0.000000e+00
# 25%    1.560000e+02  1.338957e+04   0.000000e+00    0.000000e+00
# 50%    2.390000e+02  7.487194e+04   1.420800e+04    0.000000e+00
# 75%    3.350000e+02  2.087215e+05   1.073152e+05    1.442584e+05
# max    7.430000e+02  9.244552e+07   5.958504e+07    4.958504e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    6.362620e+06    6.362620e+06  6.362620e+06    6.362620e+06
# mean     1.100702e+06    1.224996e+06  1.290820e-03    2.514687e-06
# std      3.399180e+06    3.674129e+06  3.590480e-02    1.585775e-03
# min      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# ...

# %%
# check for fraudulent transactions that destinations for TRANSFERS are also originators for CASH_OUT?
# What about in the transaction not been detected?

# %%
df.isFraud ==1
# Out:
# 0          False
# 1          False
# 2           True
# 3           True
# 4          False
#            ...
# 6362615     True
# 6362616     True
# 6362617     True
# 6362618     True
# 6362619     True
# Name: isFraud, Length: 6362620, dtype: bool

# %%
# check relationship between amount, isFraud, oldBalanceDest and newBalanceDest

df_fraudBalanceDest = df[(df['isFraud'] == 1) & 
                         (df['oldbalanceDest'] == df['newbalanceDest']) & 
                         (df['amount'] != 0)]
print(len(df_fraudBalanceDest)/len(df[df['isFraud']==1]))
print(len(df_fraudBalanceDest)/len(df[df['isFraud']==0]))
# Out:
# 0.4955558261293072
# 0.000640500364550146

# %%
df_fraudBalanceOrig = df[(df['isFraud'] == 1) & 
                         (df['oldbalanceOrg'] == df['newbalanceOrig']) & 
                         (df['amount'] != 0)]
print(len(df_fraudBalanceOrig)/len(df[df['isFraud']==1]))
print(len(df_fraudBalanceOrig)/len(df[df['isFraud']==0]))
# Out:
# 0.00499208571776452
# 6.452214974583781e-06

# %% [markdown]
# this shows that 49.5% of the fraudulent transactions have the characteristics of old balance and new balance equal while the amount is different than zero vs 0.6% for non fraudulent transactions

# %%
df['realbalanceOrig']=df['newbalanceOrig'] + df['amount'] - df['oldbalanceOrg']
df['realbalanceDest']=df['newbalanceDest'] + df['amount'] - df['oldbalanceDest']
df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
#Checking correlation between
df.corr()
# Out:
#                      step    amount  oldbalanceOrg  newbalanceOrig  \
# step             1.000000  0.022373      -0.010058       -0.010299
# amount           0.022373  1.000000      -0.002762       -0.007861
# oldbalanceOrg   -0.010058 -0.002762       1.000000        0.998803
# newbalanceOrig  -0.010299 -0.007861       0.998803        1.000000
# oldbalanceDest   0.027665  0.294137       0.066243        0.067812
# newbalanceDest   0.025888  0.459304       0.042029        0.041837
# isFraud          0.031578  0.076688       0.010154       -0.008148
# isFlaggedFraud   0.003277  0.012295       0.003835        0.003776
# realbalanceOrig  0.020516  0.970660       0.050502        0.056897
# realbalanceDest  0.010707  0.948028      -0.053157       -0.059847
#
#                  oldbalanceDest  newbalanceDest   isFraud  isFlaggedFraud  \
# step                   0.027665        0.025888  0.031578        0.003277
# amount                 0.294137        0.459304  0.076688        0.012295
# ...

# %%
# drop additional unused columns 
X['']

# %%
# binary encoding of label data "type"

# %%
# Imputation of missing data

# %%
# Features engineering
features=['type',...]

# %%
# Define X and y

X=df_preprocessed.drop['columns1','Columns2']
Y=df_preprocessed['isFraud']

# %%
# data split between training and test set 80:20 ratio
from sklearn.model_selection import train_test_split
trainX, testX, trainY, testY = train_test_split(X, Y, test_size = 0.2, \
                                                random_state = randomState)

# %%
#Check if data is balanced

# %%
#Oversampling data with SMOTE because there are very few cases of Fraud
sudo pip install imbalanced-learn

from imblearn.over_sampling import SMOTE
sm = SMOTE(sampling_strategy='minority')
X_train, y_train = sm.fit_resample(X_train, y_train.ravel())

# %%
#Check if data is balanced with SMOTE
